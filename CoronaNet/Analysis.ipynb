# %%
ls
# Out:
# Analysis.ipynb                 coronanet_release_allvars.csv
# README.md                      s41562-020-0909-7.pdf

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./coronanet_release_allvars.csv')
df.head()
# Out:
#              record_id  policy_id entry_type correct_type update_type  \
# 0  R_1gShvNnZtOkb4X1NA    3553952  new_entry     original         NaN
# 1  R_3GrLmE8y71iEe17NA    2408864  new_entry     original         NaN
# 2  R_1Hi5XBHB1zBOJc7NA    5424670  new_entry   correction         NaN
# 3  R_3EQBDJGMTKwowKOAq    2272584  new_entry   correction         NaN
# 4  R_1OoGDBSpbZQ02oANA    5468900  new_entry     original         NaN
#
#   update_level                                        description  \
# 0          NaN  Bahrain Health Ministry monitoring coronavirus...
# 1          NaN  MoH of Barbados met in press conference to dis...
# 2          NaN  On January 22, 2020, Canada implements screeni...
# 3          NaN  China announced on January 22: to guide the pr...
# 4          NaN  Xi'an, China announced that subway stations an...
#
#   date_announced  date_start date_end   country ISO_A3 ISO_A2  \
# 0     2020-01-22  2020-01-22      NaN   Bahrain    BHR     BH
# ...

# %%
df_china = df[df.country == 'China']

# %%
set(df_china.type)
# Out:
# {'Closure and Regulation of Schools',
#  'Declaration of Emergency',
#  'External Border Restrictions',
#  'Health Monitoring',
#  'Health Resources',
#  'Health Testing',
#  'Hygiene',
#  'Internal Border Restrictions',
#  'Lockdown',
#  'New Task Force, Bureau or Administrative Configuration',
#  'Other Policy Not Listed Above',
#  'Public Awareness Measures',
#  'Quarantine',
#  'Restriction and Regulation of Businesses',
#  'Restriction and Regulation of Government Services',
#  'Restrictions of Mass Gatherings',
#  'Social Distancing'}

# %%
df_china[df_china.type == 'Closure and Regulation of Schools'].type_sub_cat
# Out:
# 38       Preschool or childcare facilities (generally f...
# 39       Primary Schools (generally for children ages 1...
# 40       Secondary Schools (generally for children ages...
# 41       Higher education institutions (i.e. degree gra...
# 112      Preschool or childcare facilities (generally f...
#                                ...
# 28121    Primary Schools (generally for children ages 1...
# 28122    Secondary Schools (generally for children ages...
# 28123    Higher education institutions (i.e. degree gra...
# 28124    Primary Schools (generally for children ages 1...
# 28125    Secondary Schools (generally for children ages...
# Name: type_sub_cat, Length: 130, dtype: object

# %%
set(df_china["date_announced"])
# Out:
# {'2019-12-31',
#  '2020-01-01',
#  '2020-01-02',
#  '2020-01-04',
#  '2020-01-07',
#  '2020-01-09',
#  '2020-01-11',
#  '2020-01-16',
#  '2020-01-18',
#  '2020-01-20',
#  '2020-01-21',
#  '2020-01-22',
#  '2020-01-23',
#  '2020-01-24',
#  '2020-01-25',
#  '2020-01-26',
#  '2020-01-27',
#  '2020-01-28',
#  '2020-01-29',
#  '2020-01-30',
#  '2020-01-31',
#  '2020-02-01',
#  '2020-02-02',
#  '2020-02-03',
#  '2020-02-04',
#  '2020-02-05',
#  '2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-02-16',
#  '2020-02-17',
#  '2020-02-20',
#  '2020-02-22',
#  '2020-02-24',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-27',
#  '2020-02-28',
#  '2020-02-29',
#  '2020-03-01',
#  '2020-03-04',
#  '2020-03-05',
#  '2020-03-07',
#  '2020-03-08',
#  '2020-03-09',
#  '2020-03-10',
#  '2020-03-12',
#  '2020-03-13',
#  '2020-03-14',
#  '2020-03-15',
#  '2020-03-16',
#  '2020-03-17',
# ...
